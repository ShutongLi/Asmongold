# %% [markdown]
# ### Steam charts and google search trend

# %% [markdown]
# ### Steam reviews
# - utilize steamworks api to access user reviews (in json format). So much better than raw scraping :D
# - yes there is a library available, but might as well code a simple version ourselves!

# %%
from src import download_steam_reviews
from src import steam_analytics

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2

# %%
#download_steam_reviews.get_reviews()

# %%
data_path = 'data/steam/2021_07_27_to_2021_04_27.csv'
data = pd.read_csv(data_path)
data.head()
# Out:
#                                               review timestamp_created  \
# 0                 love this game i play it sometimes        2021/07/27
# 1                                          Cat girls        2021/07/27
# 2  WoW refugee here, I wish that I would have swi...        2021/07/27
# 3                                               nice        2021/07/27
# 4  First time playing an MMO so i have nothing to...        2021/07/27
#
#    votes_up  votes_funny  weighted_vote_score  comment_count
# 0         0            0             0.000000              0
# 1         0            0             0.000000              0
# 2         0            0             0.000000              0
# 3         1            0             0.504587              0
# 4         0            0             0.000000              0

# %%
steam_analytics.generate_relevancy_graph(data, smooth=True, N=3)

# %% [markdown]
# ### Reddit crawling

# %%
import praw

# %%
reddit = praw.Reddit(
    client_id="J7IzX_lcz-A53tAEi9qEMw",
    client_secret="8g_gN4FJSWXtm3Pbjw874rGoA59gnQ",
    user_agent="for api access to data"
)

# %%
print(reddit.read_only)
# Out:
# True
